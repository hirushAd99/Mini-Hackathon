# %% [markdown]
# Outlet Info

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
import os
os.chdir('/content/drive/My Drive/Mini_hackathon/Final')

# %%
OI = pd.read_csv('Outlet Info.csv')
OI
# Out:
#              outlet_id      region  outlet_size  population_density  \
# 0        outlet_code_1  outstation         1334                 276
# 1        outlet_code_2  outstation         1336                 276
# 2        outlet_code_3  outstation         1341                 277
# 3        outlet_code_4  outstation         1025                 239
# 4        outlet_code_5   upcountry         3965                 646
# ...                ...         ...          ...                 ...
# 4195  outlet_code_4196     western         1168                2135
# 4196  outlet_code_4197     western          791                1383
# 4197  outlet_code_4198     western         1377                2554
# 4198  outlet_code_4199     western         1289                2378
# 4199  outlet_code_4200     western          795                1390
#
#       number_of_skus_sold  average_household_income
# 0                      16                     81704
# ...

# %%
OI.isnull().sum()
# Out:
# outlet_id                   0
# region                      0
# outlet_size                 0
# population_density          0
# number_of_skus_sold         0
# average_household_income    0
# dtype: int64

# %%
dfOI = OI.copy()

# %%
unique_regions = dfOI['region'].unique()

# Print the unique values
print("Unique Regions:", unique_regions)
# Out:
# Unique Regions: ['outstation' 'upcountry' 'western']

# %%
import pandas as pd

df_encoded = pd.get_dummies(dfOI, columns=['region'], prefix='region')

# Print the DataFrame with the one-hot encoded 'outlet_region' column
print("DataFrame with One-Hot Encoded 'egion' column:")
df_encoded
# Out:
# DataFrame with One-Hot Encoded 'egion' column:
#              outlet_id  outlet_size  population_density  number_of_skus_sold  \
# 0        outlet_code_1         1334                 276                   16
# 1        outlet_code_2         1336                 276                   16
# 2        outlet_code_3         1341                 277                   16
# 3        outlet_code_4         1025                 239                   13
# 4        outlet_code_5         3965                 646                   35
# ...                ...          ...                 ...                  ...
# 4195  outlet_code_4196         1168                2135                   36
# 4196  outlet_code_4197          791                1383                   23
# 4197  outlet_code_4198         1377                2554                   44
# 4198  outlet_code_4199         1289                2378                   41
# 4199  outlet_code_4200          795                1390                   23
# ...

# %%
unique_outlet_size = dfOI['outlet_size'].unique()
print("Unique Regions:", unique_outlet_size)
# Out:
# Unique Regions: [1334 1336 1341 ... 3070 3619 2644]

# %%
import matplotlib.pyplot as plt

#Visulization between sales quantity and expected rainfall.
plt.figure(figsize=(10, 6))
plt.scatter(df_encoded['outlet_size'], df_encoded['number_of_skus_sold'], color='green', alpha=0.5)
plt.xlabel('outlet_size')
plt.ylabel('number_of_skus_sold')
plt.title('outlet_size vs. number_of_skus_sold')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

#Visulization between sales quantity and expected rainfall.
plt.figure(figsize=(10, 6))
plt.scatter(df_encoded['outlet_size'], df_encoded['population_density'], color='green', alpha=0.5)
plt.xlabel('outlet_size')
plt.ylabel('population_density')
plt.title('outlet_size vs. population_density')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

#Visulization between sales quantity and expected rainfall.
plt.figure(figsize=(10, 6))
plt.scatter(dfOI['outlet_size'], dfOI['region'], color='green', alpha=0.5)
plt.xlabel('outlet_size')
plt.ylabel('region')
plt.title('outlet_size vs. region')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

#Visulization between sales quantity and expected rainfall.
plt.figure(figsize=(10, 6))
plt.scatter(df_encoded['outlet_size'], df_encoded['average_household_income'], color='green', alpha=0.5)
plt.xlabel('outlet_size')
plt.ylabel('average_household_income')
plt.title('outlet_size vs. average_household_income')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

#Visulization between sales quantity and expected rainfall.
plt.figure(figsize=(10, 6))
plt.scatter(dfOI['average_household_income'], dfOI['region'], color='green', alpha=0.5)
plt.xlabel('average_household_income')
plt.ylabel('region')
plt.title('average_household_income vs. region')
plt.grid(True)
plt.show()

# %%
dfOI = OI.copy()

# %%
import matplotlib.pyplot as plt

#Visulization between sales quantity and expected rainfall.
plt.figure(figsize=(10, 6))
plt.scatter(dfOI['number_of_skus_sold'], dfOI['region'], color='green', alpha=0.5)
plt.xlabel('number_of_skus_sold')
plt.ylabel('region')
plt.title('number_of_skus_sold vs. region')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define rainfall bins
bins = [0, 25, 60, float('inf')]  # Adjust the bin edges
labels = ['0-25', '25-50', '50+']  # Adjust the labels

# Create a new column 'rainfall_range' with the corresponding labels
dfOI['number_of_skus_sold_range'] = pd.cut(dfOI['number_of_skus_sold'], bins=bins, labels=labels, right=False)

# Plot a bar chart to visualize the relationship
plt.figure(figsize=(10, 6))
plt.scatter(dfOI['number_of_skus_sold_range'], dfOI['region'], color='green', alpha=0.5)
plt.xlabel('number_of_skus_sold_range')
plt.ylabel('region')
plt.title('number_of_skus_sold_range vs. region')
plt.grid(True)
plt.show()

# %%
#Visulization between sales quantity and expected rainfall.
plt.figure(figsize=(10, 6))
plt.scatter(dfOI['number_of_skus_sold'], dfOI['population_density'], color='green', alpha=0.5)
plt.xlabel('number_of_skus_sold')
plt.ylabel('population_density')
plt.title('number_of_skus_sold vs. population_density')
plt.grid(True)
plt.show()

# %%
#Visulization between sales quantity and expected rainfall.
plt.figure(figsize=(10, 6))
plt.scatter(dfOI['region'], dfOI['population_density'], color='green', alpha=0.5)
plt.xlabel('region')
plt.ylabel('population_density')
plt.title('region vs. population_density')
plt.grid(True)
plt.show()

# %%
import pandas as pd

df_encoded = pd.get_dummies(dfOI, columns=['region'], prefix='region')

# Print the DataFrame with the one-hot encoded 'outlet_region' column
print("DataFrame with One-Hot Encoded 'egion' column:")
df_encoded
# Out:
# DataFrame with One-Hot Encoded 'egion' column:
#              outlet_id  outlet_size  population_density  number_of_skus_sold  \
# 0        outlet_code_1         1334                 276                   16
# 1        outlet_code_2         1336                 276                   16
# 2        outlet_code_3         1341                 277                   16
# 3        outlet_code_4         1025                 239                   13
# 4        outlet_code_5         3965                 646                   35
# ...                ...          ...                 ...                  ...
# 4195  outlet_code_4196         1168                2135                   36
# 4196  outlet_code_4197          791                1383                   23
# 4197  outlet_code_4198         1377                2554                   44
# 4198  outlet_code_4199         1289                2378                   41
# 4199  outlet_code_4200          795                1390                   23
# ...

# %%
df_encoded = pd.get_dummies(df_encoded, columns=['number_of_skus_sold_range'], prefix='number_of_skus_sold_range')

# Print or display the DataFrame with the one-hot encoded 'rainfall_range' column
print("DataFrame with One-Hot Encoded 'number_of_skus_sold_range' column:")
df_encoded
# Out:
# DataFrame with One-Hot Encoded 'number_of_skus_sold_range' column:
#              outlet_id  outlet_size  population_density  number_of_skus_sold  \
# 0        outlet_code_1         1334                 276                   16
# 1        outlet_code_2         1336                 276                   16
# 2        outlet_code_3         1341                 277                   16
# 3        outlet_code_4         1025                 239                   13
# 4        outlet_code_5         3965                 646                   35
# ...                ...          ...                 ...                  ...
# 4195  outlet_code_4196         1168                2135                   36
# 4196  outlet_code_4197          791                1383                   23
# 4197  outlet_code_4198         1377                2554                   44
# 4198  outlet_code_4199         1289                2378                   41
# ...

# %%
df_encoded.to_csv('df_encoded_OI1.csv',index=False)

# %% [markdown]
# Preprocess outlet ID
